# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamLata/Data-Science-AI/blob/main/Module_2_Reading_and_Writing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. read_csv()**
#
# read_csv() is used to read data from a CSV file into a Pandas DataFrame

# %%
import pandas as pd

df = pd.read_csv("/content/student.csv")

print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# Display First  Five Rows

# %%
import pandas as pd

df = pd.read_csv("/content/student.csv")

print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Store Using Another Variable Name

# %%
import pandas as pd

students = pd.read_csv(
    "/content/student.csv",
    usecols = [
        "sex",
        "G1",
        "G2"
    ]

)
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# **2. read_excel()**
#
# read_excel() is used
#
# **Prerequisite:**
#
# To read excel files, install the openpyxl library.
#
# pip install openpyxl

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
df.to_excel("Student.xlsx", index=False)
print("CSV successfully converted to excel!")
# Out:
# CSV successfully converted to excel!

# %% [markdown]
# Read Excel File

# %%
import pandas as pd

df = pd.read_excel("/content/Student.xlsx")
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# **Display First Five Rows**

# %%
import pandas as pd
df = pd.read_excel("/content/Student.xlsx")
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# **Display last five rows**

# %%
import pandas as pd
df = pd.read_excel("/content/Student.xlsx")
print(df.tail())
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# **Read selected columns**

# %%
import pandas as pd
df = pd.read_excel(
    "/content/Student.xlsx",
    usecols = [
        "sex",
        "G1",
        "G2"
    ]
)
print(df)
# Out:
#     sex  G1  G2
# 0     F   5   6
# 1     F   5   5
# 2     F   7   8
# 3     F  15  14
# 4     F   6  10
# ..   ..  ..  ..
# 390   M   9   9
# 391   M  14  16
# 392   M  10   8
# 393   M  11  12
# 394   M   8   9
#
# [395 rows x 3 columns]

# %% [markdown]
# **3.Read JSON()**
#
# JSON(javaScript Object Notation) is a lightweight data-interchange format.
# it stores data as key-value pairs.

# %%
import pandas as pd
#read csv file
df = pd.read_csv("/content/student.csv")
df.to_json("student.json",orient = "records", index=4)

# %% [markdown]
# display One Random Student

# %%
import pandas as pd

df = pd.read_csv("/content/student.csv")

print(df.sample())
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 332     GP   F   18       U     GT3       T     3     3  services  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 332  ...      5        3      4     1     1      4        0  7  0  0
#
# [1 rows x 33 columns]

# %% [markdown]
# Select 30% of Dataset

# %%
import pandas as pd

df = pd.read_csv("/content/student.csv")

print(df.sample(frac=0.3))
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 202     GP   F   17       U     GT3       T     1     1     other     other
# 117     GP   M   16       U     GT3       T     3     3     other  services
# 230     GP   F   17       U     LE3       T     4     3    health     other
# 175     GP   M   17       U     LE3       T     4     3   teacher     other
# 86      GP   F   16       U     LE3       T     2     2   at_home     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 94      GP   M   15       U     LE3       T     2     2  services    health
# 92      GP   F   16       U     LE3       T     3     1     other     other
# 305     GP   F   18       U     GT3       T     2     4  services   at_home
# 173     GP   F   16       U     GT3       T     1     3   at_home  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 202  ...      4        4      4     1     3      1        4   9   9  10
# 117  ...      5        4      2     1     1      5        0  13  14  13
# 230  ...      3        2      3     1     2      3       14  13  13  14
# 175  ...      4        4      4     4     4      4        4  10   9   9
# 86   ...      4        3      4     1     2      2        4   8   7   6
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 110  ...      5        5      3     1     1      4        6  18  19  19
# 94   ...      4        3      4     1     1      4        6  11  13  14
# 92   ...      3        3      3     2     3      2        4   7   6   6
# 305  ...      4        4      3     1     1      3        8  14  12  12
# 173  ...      4        3      5     1     1      3        0   8   7   0
#
# [118 rows x 33 columns]

# %% [markdown]
# Random Student from Excel File

# %%
import pandas as pd

df = pd.read_excel("/content/student.csv")

print(df.sample(3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_845/3348121455.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("/content/student.csv")
#       4
#       5 print(df.sample(3))
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1552                 )
#    1553                 if ext is None:
# -> 1554                     raise ValueError(
#    1555                         "Excel file format cannot be determined, you must specify "
#    1556                         "an engine manually."
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.
